# %% [markdown]
# # DAGMM Example
# - In this example, anomaly scores of Mixture of Gaussian sample with 2 artificial "Outlier" are calculated.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs

from dagmm_v2 import DAGMM

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Generate sample data
# - Generate random samples from Mixture of Gaussian
# - To check validity of logic, 2 aritificial "Outliers" is mixed to them.

# %%
data, _ = make_blobs(n_samples=1000, n_features=5, centers=5, random_state=123)

# %%
data[300] = [-1, -1, -1, -1, -1]
data[500] = [ 1,  0,  1,  1,  1]
ano_index = [300, 500]
data
# Out:
# array([[ 2.54386451,  6.83883395,  4.89575896,  1.63080062,  4.78086488],
#        [-1.68591434, 11.49358717,  5.48305585, -0.15955649, -2.85384455],
#        [-1.4680692 , 10.16194241,  2.37002801, -0.79319555, -2.81092007],
#        ...,
#        [ 0.54535312,  8.99952183,  3.60223423,  0.08908825, -2.53512283],
#        [-5.24758494,  4.49899574, -2.50690074, -7.60230568, -1.33514656],
#        [ 3.77353457, -3.50351896, -6.2711263 ,  1.71469713,  5.44963508]])

# %% [markdown]
# ### Scatter plot
# Red Points are mixed "Outliers"

# %%
data[0,:]
# Out:
# array([2.54386451, 6.83883395, 4.89575896, 1.63080062, 4.78086488])

# %%
plt.figure(figsize=[8,8])
plt.plot(data[:,0], data[:,1], ".")
plt.plot(data[ano_index,0], data[ano_index,1], "o", c="r", markersize=10)

# %% [markdown]
# ## DAGMM

# %%
# tf.reset_default_graph()

# %%
model_dagmm = DAGMM(
    comp_hiddens=[16,8,1], comp_activation=tf.nn.tanh,
    est_hiddens=[8,4], est_activation=tf.nn.tanh, est_dropout_ratio=0.25,
    epoch_size=1000, minibatch_size=128
)

# %%
model_dagmm.fit(data)
# Out:
# /mnt/d/GitHub/DAGMM/dagmm_v2/compression_net.py:37: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   z = tf.compat.v1.layers.dense(z, size, activation=self.activation,
# /home/aytac/miniconda3/envs/shapefile/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:255: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /mnt/d/GitHub/DAGMM/dagmm_v2/compression_net.py:42: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   z = tf.compat.v1.layers.dense(z, self.hidden_layer_sizes[-1],
# /mnt/d/GitHub/DAGMM/dagmm_v2/compression_net.py:52: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   z = tf.compat.v1.layers.dense(z, size, activation=self.activation,
# /mnt/d/GitHub/DAGMM/dagmm_v2/compression_net.py:57: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   x_dash = tf.compat.v1.layers.dense(z, self.input_size,
# /mnt/d/GitHub/DAGMM/dagmm_v2/estimation_net.py:48: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   z = tf.compat.v1.layers.dense(z, size, activation=self.activation,
# /mnt/d/GitHub/DAGMM/dagmm_v2/estimation_net.py:51: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   z = tf.compat.v1.layers.dropout(z, dropout_ratio,
# /home/aytac/miniconda3/envs/shapefile/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:401: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs, training=training)
# /mnt/d/GitHub/DAGMM/dagmm_v2/estimation_net.py:56: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   logits = tf.compat.v1.layers.dense(z, size, activation=None, name="logits")
# 2023-02-22 00:12:00.591835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:00.923403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:00.924127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:00.928520: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-22 00:12:00.932426: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:00.933138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:00.933800: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:03.314912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:03.316643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:03.316732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-02-22 00:12:03.317484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-22 00:12:03.317604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2742 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2023-02-22 00:12:04.959620: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x5556c10ea070
#  epoch 100/1000 : loss = 2.196
#  epoch 200/1000 : loss = 1.994
#  epoch 300/1000 : loss = 1.841
#  epoch 400/1000 : loss = 1.632
#  epoch 500/1000 : loss = 1.408
#  epoch 600/1000 : loss = 1.223
#  epoch 700/1000 : loss = 0.998
#  epoch 800/1000 : loss = 0.837
#  epoch 900/1000 : loss = 0.750
#  epoch 1000/1000 : loss = 0.700

# %%
energy = model_dagmm.predict(data)

# %%
plt.figure(figsize=[8,3])
histinfo = plt.hist(energy, bins=50)
plt.xlabel("DAGMM Energy")
plt.ylabel("Number of Sample(s)")
# Out:
# Text(0, 0.5, 'Number of Sample(s)')

# %%
plt.figure(figsize=[8,3])
plt.plot(energy, "o-")
plt.xlabel("Index (row) of Sample")
plt.ylabel("Energy")
# Out:
# Text(0, 0.5, 'Energy')

# %% [markdown]
# ### Matrix Scatter Plot
# - If an energy of sample exceeds 99th percentile of enegies, it is recognized as "Outlier".
#     - In plot below, it is marked red "x".
# - Two "outlier" points are precisely recognized.

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=[12,12], sharex=True, sharey=True)
plt.subplots_adjust(wspace=0.05, hspace=0.05)

for row in range(5):
    for col in range(5):
        ax = axes[row, col]
        if row != col:
            ax.plot(data[:,col], data[:,row], ".")
            ano_index = np.arange(len(energy))[energy > np.percentile(energy, 99)]
            ax.plot(data[ano_index,col], data[ano_index,row], "x", c="r", markersize=8)
